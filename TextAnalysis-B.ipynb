# %%
# Dela Rosa, Quielle Xyrone, 181603
# Carl Alden Go, 182216
# Margarita Juliana Perez, 183848

# October 19, 2021

# I certify that this submission complies with the DISCS Academic Integrity
# Policy.

# If I have discussed my Python language code with anyone other than
# my instructor(s), my/our groupmate(s), the teaching assistant(s),
# the extent of each discussion has been clearly noted along with a proper
# citation in the comments of my program.

# If any Python language code or documentation used in my program
# was obtained from another source, either modified or unmodified, such as a
# textbook, website, or another individual, the extent of its use has been
# clearly noted along with a proper citation in the comments of my program.

################################################################################

# %%
# !pip install seaborn wordcloud
# Out:
# Requirement already satisfied: seaborn in c:\programdata\miniconda3\lib\site-packages (0.11.2)
# Requirement already satisfied: wordcloud in c:\programdata\miniconda3\lib\site-packages (1.8.1)
# Requirement already satisfied: numpy>=1.15 in c:\programdata\miniconda3\lib\site-packages (from seaborn) (1.21.2)
# Requirement already satisfied: pandas>=0.23 in c:\programdata\miniconda3\lib\site-packages (from seaborn) (1.3.2)
# Requirement already satisfied: scipy>=1.0 in c:\programdata\miniconda3\lib\site-packages (from seaborn) (1.7.1)
# Requirement already satisfied: matplotlib>=2.2 in c:\programdata\miniconda3\lib\site-packages (from seaborn) (3.4.3)
# Requirement already satisfied: cycler>=0.10 in c:\programdata\miniconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (0.10.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\programdata\miniconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\programdata\miniconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (8.3.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\programdata\miniconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (1.3.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\programdata\miniconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (2.4.7)
# Requirement already satisfied: six in c:\programdata\miniconda3\lib\site-packages (from cycler>=0.10->matplotlib>=2.2->seaborn) (1.16.0)
# Requirement already satisfied: pytz>=2017.3 in c:\programdata\miniconda3\lib\site-packages (from pandas>=0.23->seaborn) (2021.1)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.style as style
from wordcloud import WordCloud
style.use('fivethirtyeight')
sns.set(rc={'figure.figsize':(12,6)})

# %%
# Read cleaned tweets, term frequencies of DTM, ngram, and TFIDF
freq_dtm = pd.read_csv('out/frequency_dtm.csv', index_col=None, header=0)
freq_ngram = pd.read_csv('out/frequency_ngram.csv', index_col=None, header=0)
freq_tfidf = pd.read_csv('out/frequency_tfidf.csv', index_col=None, header=0)
cleaned_tweets = pd.read_csv('out/cleaned_tweets.csv', index_col=None, header=0)
cleaned_tweets.head()
# Out:
#                                                 text  \
# 0  Finished sex education season 3  didn't like t...
# 1  Currently half way through season 3 of Sex edu...
# 2  season 3 of Sex Education has such a good soun...
# 3  @JWRD__ - You season 3 , sex education season ...
# 4  on episode 6 season 3 of sex education and i'v...
#
#                                         cleaned_text
# 0                            didnt like cliff hanger
# 1  currently half way absolutely clue addictive w...
# 2                                    good soundtrack
# 3                         film de slag om de schelde
# 4                       never want smack anyone otis

# %% [markdown]
# ### Visualization of term frequencies

# %%
# Visualize frequencies
#sns.barplot(data=freq_dtm.head(10), x='term',
 #           y='frequency').set_title('Frequent terms in DTM')

# %%
# Visualize frequencies
sns.barplot(data=freq_ngram.head(15), x='frequency',
            y='term', palette='rainbow_r').set_title('Frequent terms in Ngram')
# Out:
# Text(0.5, 1.0, 'Frequent terms in Ngram')

# %%
# Visualize frequencies
sns.barplot(data=freq_tfidf.head(15), x='term',
            y='frequency', palette='rainbow_r').set_title('Frequent terms in TFIDF')
# Out:
# Text(0.5, 1.0, 'Frequent terms in TFIDF')

# %% [markdown]
# ### Wordcloud

# %%
def create_wordcloud(tweets, max_words=500):
    """Create a wordcloud of most common words in a set of tweets"""
    
    # Transform text for WordCloud
    tweets = tweets['cleaned_text']
    tweets = tweets.dropna()
    tweets = ' '.join(tweets)
    tweets = tweets.replace(' ', ',')
    
    # Generate wordcloud image
    wc = WordCloud(background_color="white", max_words=max_words, colormap='spring')
    wc.generate(tweets)
    plt.imshow(wc, interpolation='bilinear')
    plt.title('Twitter Generated Cloud', size=30)
    plt.axis("off")
    
# Generate a wordcloud
create_wordcloud(cleaned_tweets)
